# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="biblioteca"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM libros")

result = mycursor.fetchall()

for x in result:
  print(x)


  mycursor = mydb.cursor()

sql = "SELECT * FROM libros WHERE Autor ='Oracle'"

mycursor.execute(sql)

resultados = mycursor.fetchall()

for x in resultados:
  print(x)

  mycursor = mydb.cursor()

sql = "SELECT * FROM libros ORDER BY Autor"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)

Schopenhauer = mydb.cursor()

sql = "SELECT * FROM libros WHERE Autor ='Arthur Schopenhauer'"

Schopenhauer.execute(sql)

Schopenhauers = mycursor.fetchall()

for s in Schopenhauers:
  print(s)
  #pip install matplotlib
  import matplotlib
  import matplotlib.pyplot as plt
  import numpy
  import numpy as np
print(matplotlib.__version__)
ra = np.array([35, 25, 25, 15])

plt.pie(ra)
plt.show()

import json 
# RFC 4627
# echo '{"json":"obj"}' | python -m json.tool

book = {"books": [
  {
  "_id": {
    "$oid": "5fd130823af861094c326608"
  },
  "Autor": "Hesiodo",
  "Titulo": "Obras y fragmentos",
  "Genero": "Grecolatino",
  "Editorial": "Gredos",
  "Item": 3,
  "Image": "https://www.rbalibros.com/medio/2020/12/04/22-obras-y-fragmentos_f383a9cf_500x793.jpg",
  "Info": ""
},{
  "_id": {
    "$oid": "5fd130823af861094c32660a"
  },
  "Autor": "Sófocles",
  "Titulo": "Tragedias",
  "Genero": "Grecolatino",
  "Editorial": "Gredos",
  "Item": 5
},{
  "_id": {
    "$oid": "5fd130823af861094c32660e"
  },
  "Autor": "Esopo",
  "Titulo": "Fábulas. Vida de Esopo",
  "Genero": "Grecolatino",
  "Editorial": "Gredos",
  "Item": 9
  }]
}


dumpx = json.dumps(book)

# the result is a JSON string:
print(dumpx)



# dbs = pd.DataFrame(book['books'])
# print (dbs)
# dbs.plot(x='item', y='item')
# y = np.array([35, 25, 25, 15])
# mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
# mycolors = ["black", "hotpink", "b", "#4CAF50"]

# plt.pie(y, labels = mylabels, colors = mycolors)
# plt.show() 


x = numpy.random.uniform(0.0, 5.0, 250)

print(x)

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.ylabel("yyy")
plt.show()
# pip install pandas
import pandas
import pandas as pd

df = pd.read_json('datas.json')

print(df.to_string()) 

# create dataframe
df_html = pd.DataFrame({'nombre': ['Mono', 'Mona', 'Kiko', 'Lenin'],
     'Base de datos': [6.8, 7.4, 7.7, 7.8],
     'Desarollo web': [8.4, 5.6, 7.3, 6.9],
     'Progrmación': [7.8, 8.8, 8.2, 8.7]})

# render dataframe  html
html = df_html.to_html()
print(html)
#ecribir html a archivo
text_file = open("dataframe.html", "w")
text_file.write(html)
#text_file.close()

dtypes = ['int64', 'float64', 'complex128', 'object', 'bool']
data = dict([(t, np.ones(shape=5000, dtype=int).astype(t))
             for t in dtypes])
df = pd.DataFrame(data)
df.head()

d = {"votacion": [
           {
               "Partido": 1,
               "Votos": 537.27713514 ,
               "Nombre": "PRI"
           },
           {
               "Partido": 2,
               "Votos": 656.59174681,
               "Nombre": "PAN"
           }
]}
df = pd.DataFrame(d['votacion'])
print (df)
df.plot(x='Votos', y='Partido')
# Out:
# (1, 'Homero', 'La Iliada', 'Gredos', 'Grecolatino', 'https://www.rbalibros.com/medio/2019/11/15/cover_iliada_ok_a34cbfaf_500x796.jpg', 'Una obra Maestra', 1)
# (2, 'Homero', 'La Odisea', 'Gredos', 'Grecolatino', 'https://www.rbalibros.com/medio/2019/10/11/odisea_cover_nuevabcg_913048a4_500x801.jpg', None, 2)
# (3, 'Hesiodo', 'Obras y fragmentos', 'Gredos', 'Grecolatino', 'https://www.rbalibros.com/medio/2020/12/04/22-obras-y-fragmentos_f383a9cf_500x793.jpg', None, 3)
# (4, 'Esquilo', 'Tragedias', 'Gredos', 'Grecolatino', 'https://www.rbalibros.com/medio/2019/05/31/369_6b5032ae_500x759.jpg', None, 4)
# (5, 'Sófocles', 'Tragedias', 'Gredos', 'Grecolatino', None, None, 5)
# (6, 'Eurípides', 'Tragedias I', 'Gredos', 'Grecolatino', None, None, 6)
# (7, 'Eurípides', 'Tragedias II', 'Gredos', 'Grecolatino', None, None, 7)
# (8, 'Eurípides', 'Tragedias III', 'Gredos', 'Grecolatino', None, None, 8)
# (9, 'Esopo', 'Fábulas. Vida de Esopo', 'Gredos', 'Grecolatino', None, None, 9)
# ...
